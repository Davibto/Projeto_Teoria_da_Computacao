# %%
#pip install automata-lib

# %%
#pip install pandas

# %%
#pip install graphviz

# %%
#pip install colormath

# %%
#pip install jupyterlab

# %%
#pip install visual-automata

# %%
from automata.fa.dfa import DFA
from visual_automata.fa.dfa import VisualDFA

# %run main.py
visual_dfa = VisualDFA(afd)
visual_dfa.show_diagram()

# %%
from automata.fa.dfa import DFA
from visual_automata.fa.dfa import VisualDFA

# %run teste.py

visual_dfa = VisualDFA(afd)
visual_dfa.show_diagram()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Vscode\Python\MinimizadorAFD\Projeto_Teoria_da_Computacao\teste.py:29
#      12     print('Nao foi possivel gerar um AFD a partir do arquivo dado.')
#      14 else:
#      15     # print("Alfabeto:")
#      16     # print(afd.alfabeto)
#    (...)
#      26     # print(afd.valido())
#      27     # print(afd.transicoes_tabela);
# ---> 29     MinimizadorAFD().minimizar(afd)
#      30     afd = afd.afd_para_visual_dfa(MinimizadorAFD().estados_novos, MinimizadorAFD().inicial_novo,  MinimizadorAFD().finais_novos, MinimizadorAFD().tabela_transicoes_nova)
#
# File ~\Vscode\Python\MinimizadorAFD\Projeto_Teoria_da_Computacao\minimizador.py:103, in MinimizadorAFD.minimizar(afd)
#      96     break
#      98 # print("Pares nao marcados (possiveis equivalentes):")
#      99 # print(pares_nao_marcados)
#     100 # print("Pares marcados (nao equivalentes):")
#     101 # print(pares_marcados)
# --> 103 MinimizadorAFD.juntar_estados(pares_nao_marcados, afd)
#
# File ~\Vscode\Python\MinimizadorAFD\Projeto_Teoria_da_Computacao\minimizador.py:203, in MinimizadorAFD.juntar_estados(pares_nao_marcados, afd)
#     201 estado = copia_estados_novos[k]
#     202 for i in range(linha):
# --> 203     if afd.transicoes_tabela[i+1][0] in estado:
#     204         # print('estado tabela: ', afd.transicoes_tabela[i+1][0], ' estado novo: ', estado)
#     205         for j in range(len(afd.alfabeto)):
#     206             simbolos.append(afd.transicoes_tabela[i+1][j+1])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 7
#       4 get_ipython().run_line_magic('run', 'teste.py')
#       6 visual_dfa = VisualDFA(afd)
# ----> 7 visual_dfa.show_diagram()
#
# File ~\anaconda3\lib\site-packages\visual_automata\fa\dfa.py:400, in VisualDFA.show_diagram(self, input_str, filename, format_type, path, view, cleanup, horizontal, reverse_orientation, fig_size, font_size, arrow_size, state_seperation)
#     397 graph.node("Initial", label="", shape="point", fontsize=font_size)
#     399 # Defining all states.
# --> 400 for state in sorted(self.dfa.states):
#     401     if (
#     402         state in self.dfa.initial_state and state in
#     403         self.dfa.final_states
#     404     ):
#     405         graph.node(state, shape="doublecircle", fontsize=font_size)
#
# AttributeError: 'AFD' object has no attribute 'states'
